# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm
import torch
import torch.nn as nn
from torch.nn import Parameter
import sys
sys.path.append('../')
import probtorch
from probtorch.util import expand_inputs
print('probtorch:', probtorch.__version__, 
      'torch:', torch.__version__, 
      'cuda:', torch.cuda.is_available())
# Out:
# probtorch: 0.0+5a2c637 torch: 0.4.0a0+29c3890 cuda: True

# %% [markdown]
# # Parameters

# %%
# model parameters
NUM_PIXELS = 784
NUM_HIDDEN = 256
NUM_DIGITS = 10
NUM_STYLE = 50   

# training parameters
NUM_SAMPLES = 8 
NUM_BATCH = 128
NUM_EPOCHS = 200
LABEL_FRACTION = 0.1
LEARNING_RATE = 1e-3
BETA1 = 0.90
EPS = 1e-9
#CUDA = torch.cuda.is_available()
CUDA = True

# path parameters
MODEL_NAME = 'mnist-semisupervised-iwae-%02ddim' % NUM_STYLE
DATA_PATH = '../data'
WEIGHTS_PATH = '../weights'
RESTORE = False

# %% [markdown]
# # Encoder Model

# %%
class Encoder(nn.Module):
    def __init__(self, num_pixels=NUM_PIXELS, 
                       num_hidden=NUM_HIDDEN,
                       num_digits=NUM_DIGITS,
                       num_style=NUM_STYLE,
                       num_batch=NUM_BATCH):
        super(self.__class__, self).__init__()
        self.enc_hidden = nn.Sequential( 
                            nn.Linear(num_pixels, num_hidden),
                            nn.ReLU())
        self.digit_log_weights = nn.Linear(num_hidden, num_digits)
        self.digit_temp = torch.tensor(0.66)
        self.style_mean = nn.Linear(num_hidden + num_digits, num_style)
        self.style_log_std = nn.Linear(num_hidden + num_digits, num_style)
    
    @expand_inputs
    def forward(self, images, labels=None, num_samples=None):
        q = probtorch.Trace()
        hiddens = self.enc_hidden(images)
        digits = q.concrete(logits=self.digit_log_weights(hiddens),
                            temperature=self.digit_temp,
                            value=labels,
                            name='digits')
        hiddens2 = torch.cat([digits, hiddens], -1)
        styles_mean = self.style_mean(hiddens2)
        styles_std = torch.exp(self.style_log_std(hiddens2))
        q.normal(styles_mean,
                 styles_std,
                 name='styles')
        return q

# %% [markdown]
# # Decoder Model

# %%
class Decoder(nn.Module):
    def __init__(self, num_pixels=NUM_PIXELS, 
                       num_hidden=NUM_HIDDEN,
                       num_digits=NUM_DIGITS,
                       num_style=NUM_STYLE):
        super(self.__class__, self).__init__()
        self.num_digits = num_digits
        self.digit_log_weights = torch.zeros(num_digits)
        self.digit_temp = torch.tensor(0.66)
        self.style_mean = torch.zeros(num_style)
        self.style_std = torch.ones(num_style)
        self.dec_hidden = nn.Sequential(
                            nn.Linear(num_style + num_digits, num_hidden),
                            nn.ReLU())
        self.dec_image = nn.Sequential(
                           nn.Linear(num_hidden, num_pixels),
                           nn.Sigmoid())

    def forward(self, images, q=None, num_samples=None):
        p = probtorch.Trace()
        digits = p.concrete(logits=self.digit_log_weights,
                            temperature=self.digit_temp,
                            value=q['digits'],
                            name='digits')
        styles = p.normal(self.style_mean, 
                          self.style_std,
                          value=q['styles'],
                          name='styles')
        hiddens = self.dec_hidden(torch.cat([digits, styles], -1))
        images_mean = self.dec_image(hiddens)
        p.loss(lambda x_hat, x: -(torch.log(x_hat + EPS) * x + 
                                  torch.log(1 - x_hat + EPS) * (1-x)).sum(-1),
               images_mean, images, name='images')
        return p

# %% [markdown]
# # Loss

# %%
def elbo(q, p, alpha=0.1):
    if NUM_SAMPLES is None:
        return probtorch.objectives.importance.elbo(q, p, sample_dim=None, batch_dim=0, alpha=alpha)
    else:
        return probtorch.objectives.importance.elbo(q, p, sample_dim=0, batch_dim=1, alpha=alpha)

# %% [markdown]
# # Data

# %%
from torchvision import datasets, transforms
import os 

if not os.path.isdir(DATA_PATH):
    os.makedirs(DATA_PATH)

train_data = torch.utils.data.DataLoader(
                datasets.MNIST(DATA_PATH, train=True, download=True,
                               transform=transforms.ToTensor()),
                batch_size=NUM_BATCH, shuffle=True) 
test_data = torch.utils.data.DataLoader(
                datasets.MNIST(DATA_PATH, train=False, download=True,
                               transform=transforms.ToTensor()),
                batch_size=NUM_BATCH, shuffle=True)

# %% [markdown]
# # Training and Testing

# %%
def cuda_tensors(obj): 
    for attr in dir(obj):
        value = getattr(obj, attr)
        if isinstance(value, torch.Tensor):
            setattr(obj, attr, value.cuda())

enc = Encoder()
dec = Decoder()
if CUDA:
    enc.cuda()
    dec.cuda()
    cuda_tensors(enc)
    cuda_tensors(dec)

optimizer =  torch.optim.Adam(list(enc.parameters())+list(dec.parameters()),
                              lr=LEARNING_RATE,
                              betas=(BETA1, 0.999))

# %%
def train(data, enc, dec, optimizer, 
          label_mask={}, label_fraction=LABEL_FRACTION):
    epoch_elbo = 0.0
    enc.train()
    dec.train()
    N = 0
    for b, (images, labels) in enumerate(data):
        if images.size()[0] == NUM_BATCH:
            N += NUM_BATCH
            images = images.view(-1, NUM_PIXELS)
            labels_onehot = torch.zeros(NUM_BATCH, NUM_DIGITS)
            labels_onehot.scatter_(1, labels.unsqueeze(1), 1)
            labels_onehot = torch.clamp(labels_onehot, EPS, 1-EPS)
            if CUDA:
                images = images.cuda()
                labels_onehot = labels_onehot.cuda()
            optimizer.zero_grad()
            if b not in label_mask:
                label_mask[b] = (random() < label_fraction)
            if label_mask[b]:
                q = enc(images, labels_onehot, num_samples=NUM_SAMPLES)
            else:
                q = enc(images, num_samples=NUM_SAMPLES)
            p = dec(images, q, num_samples=NUM_SAMPLES)
            loss = -elbo(q, p)
            loss.backward()
            optimizer.step()
            if CUDA:
                loss = loss.cpu()
            epoch_elbo -= float(loss.item())
    return epoch_elbo / N, label_mask

def test(data, enc, dec, infer=True):
    enc.eval()
    dec.eval()
    epoch_elbo = 0.0
    epoch_correct = 0
    N = 0
    for b, (images, labels) in enumerate(data):
        if images.size()[0] == NUM_BATCH:
            N += NUM_BATCH
            images = images.view(-1, NUM_PIXELS)
            if CUDA:
                images = images.cuda()
            q = enc(images, num_samples=NUM_SAMPLES)
            p = dec(images, q, num_samples=NUM_SAMPLES)
            batch_elbo = elbo(q, p)
            if CUDA:
                batch_elbo = batch_elbo.cpu()
            epoch_elbo += float(batch_elbo.item())
            if infer:
                log_p = p.log_joint(0, 1)
                log_q = q.log_joint(0, 1)
                log_w = log_p - log_q
                w = torch.nn.functional.softmax(log_w, 0)
                y_samples = q['digits'].value
                y_expect = (w.unsqueeze(-1) * y_samples).sum(0)
                _ , y_pred = y_expect.max(-1)
                if CUDA:
                    y_pred = y_pred.cpu()
                epoch_correct += float((labels == y_pred).sum())
            else:
                _, y_pred = q['digits'].value.max(-1)
                if CUDA:
                    y_pred = y_pred.cpu()
                epoch_correct += float((labels == y_pred).sum()) / (NUM_SAMPLES or 1.0)
    return epoch_elbo / N, epoch_correct / N

# %%
import time
from random import random
if not RESTORE:
    mask = {}
    for e in range(NUM_EPOCHS):
        train_start = time.time()
        train_elbo, mask = train(train_data, enc, dec, 
                                 optimizer, mask, LABEL_FRACTION)
        train_end = time.time()
        test_start = time.time()
        test_elbo, test_accuracy = test(test_data, enc, dec)
        test_end = time.time()
        print('[Epoch %d] Train: ELBO %.4e (%ds) Test: ELBO %.4e, Accuracy %0.3f (%ds)' % (
                e, train_elbo, train_end - train_start, 
                test_elbo, test_accuracy, test_end - test_start))

    if not os.path.isdir(WEIGHTS_PATH):
        os.mkdir(WEIGHTS_PATH)
    torch.save(enc.state_dict(),
               '%s/%s-%s-%s-enc.rar' % (WEIGHTS_PATH, MODEL_NAME, probtorch.__version__, torch.__version__))
    torch.save(dec.state_dict(),
               '%s/%s-%s-%s-dec.rar' % (WEIGHTS_PATH, MODEL_NAME, probtorch.__version__, torch.__version__))
# Out:
# [Epoch 0] Train: ELBO -1.3309e+00 (6s) Test: ELBO -1.0674e+00, Accuracy 0.099 (0s)
# [Epoch 1] Train: ELBO -1.0165e+00 (6s) Test: ELBO -9.6164e-01, Accuracy 0.100 (0s)
# [Epoch 2] Train: ELBO -9.4179e-01 (6s) Test: ELBO -9.0939e-01, Accuracy 0.102 (0s)
# [Epoch 3] Train: ELBO -9.0115e-01 (6s) Test: ELBO -8.7991e-01, Accuracy 0.105 (0s)
# [Epoch 4] Train: ELBO -8.7549e-01 (6s) Test: ELBO -8.5638e-01, Accuracy 0.327 (0s)
# [Epoch 5] Train: ELBO -8.5560e-01 (6s) Test: ELBO -8.3958e-01, Accuracy 0.629 (0s)
# [Epoch 6] Train: ELBO -8.4097e-01 (6s) Test: ELBO -8.2773e-01, Accuracy 0.701 (0s)
# [Epoch 7] Train: ELBO -8.3127e-01 (6s) Test: ELBO -8.2099e-01, Accuracy 0.722 (0s)
# [Epoch 8] Train: ELBO -8.2395e-01 (6s) Test: ELBO -8.1429e-01, Accuracy 0.737 (0s)
# [Epoch 9] Train: ELBO -8.1796e-01 (6s) Test: ELBO -8.0842e-01, Accuracy 0.749 (0s)
# [Epoch 10] Train: ELBO -8.1292e-01 (6s) Test: ELBO -8.0425e-01, Accuracy 0.769 (0s)
# [Epoch 11] Train: ELBO -8.0861e-01 (6s) Test: ELBO -8.0185e-01, Accuracy 0.779 (0s)
# [Epoch 12] Train: ELBO -8.0493e-01 (6s) Test: ELBO -7.9780e-01, Accuracy 0.789 (0s)
# [Epoch 13] Train: ELBO -8.0177e-01 (6s) Test: ELBO -7.9503e-01, Accuracy 0.808 (0s)
# [Epoch 14] Train: ELBO -7.9889e-01 (6s) Test: ELBO -7.9270e-01, Accuracy 0.818 (0s)
# [Epoch 15] Train: ELBO -7.9649e-01 (6s) Test: ELBO -7.9086e-01, Accuracy 0.832 (0s)
# [Epoch 16] Train: ELBO -7.9431e-01 (6s) Test: ELBO -7.8956e-01, Accuracy 0.840 (0s)
# [Epoch 17] Train: ELBO -7.9206e-01 (6s) Test: ELBO -7.8690e-01, Accuracy 0.850 (0s)
# [Epoch 18] Train: ELBO -7.9027e-01 (6s) Test: ELBO -7.8529e-01, Accuracy 0.853 (0s)
# [Epoch 19] Train: ELBO -7.8841e-01 (6s) Test: ELBO -7.8441e-01, Accuracy 0.856 (0s)
# [Epoch 20] Train: ELBO -7.8720e-01 (6s) Test: ELBO -7.8225e-01, Accuracy 0.864 (0s)
# [Epoch 21] Train: ELBO -7.8543e-01 (6s) Test: ELBO -7.8074e-01, Accuracy 0.866 (0s)
# [Epoch 22] Train: ELBO -7.8432e-01 (6s) Test: ELBO -7.7997e-01, Accuracy 0.866 (0s)
# [Epoch 23] Train: ELBO -7.8324e-01 (6s) Test: ELBO -7.7931e-01, Accuracy 0.876 (0s)
# [Epoch 24] Train: ELBO -7.8195e-01 (6s) Test: ELBO -7.7861e-01, Accuracy 0.879 (0s)
# [Epoch 25] Train: ELBO -7.8088e-01 (6s) Test: ELBO -7.7751e-01, Accuracy 0.880 (0s)
# [Epoch 26] Train: ELBO -7.8005e-01 (6s) Test: ELBO -7.7559e-01, Accuracy 0.881 (0s)
# [Epoch 27] Train: ELBO -7.7891e-01 (6s) Test: ELBO -7.7558e-01, Accuracy 0.885 (0s)
# [Epoch 28] Train: ELBO -7.7828e-01 (6s) Test: ELBO -7.7452e-01, Accuracy 0.886 (0s)
# [Epoch 29] Train: ELBO -7.7756e-01 (6s) Test: ELBO -7.7390e-01, Accuracy 0.892 (0s)
# [Epoch 30] Train: ELBO -7.7664e-01 (6s) Test: ELBO -7.7288e-01, Accuracy 0.890 (0s)
# [Epoch 31] Train: ELBO -7.7597e-01 (6s) Test: ELBO -7.7212e-01, Accuracy 0.893 (0s)
# [Epoch 32] Train: ELBO -7.7534e-01 (6s) Test: ELBO -7.7179e-01, Accuracy 0.894 (0s)
# [Epoch 33] Train: ELBO -7.7467e-01 (6s) Test: ELBO -7.7151e-01, Accuracy 0.891 (0s)
# [Epoch 34] Train: ELBO -7.7403e-01 (6s) Test: ELBO -7.7061e-01, Accuracy 0.895 (0s)
# [Epoch 35] Train: ELBO -7.7353e-01 (6s) Test: ELBO -7.6988e-01, Accuracy 0.892 (0s)
# [Epoch 36] Train: ELBO -7.7276e-01 (6s) Test: ELBO -7.7055e-01, Accuracy 0.898 (0s)
# [Epoch 37] Train: ELBO -7.7223e-01 (6s) Test: ELBO -7.7109e-01, Accuracy 0.905 (0s)
# [Epoch 38] Train: ELBO -7.7191e-01 (6s) Test: ELBO -7.6995e-01, Accuracy 0.905 (0s)
# [Epoch 39] Train: ELBO -7.7137e-01 (6s) Test: ELBO -7.6826e-01, Accuracy 0.906 (0s)
# [Epoch 40] Train: ELBO -7.7091e-01 (6s) Test: ELBO -7.6827e-01, Accuracy 0.903 (0s)
# [Epoch 41] Train: ELBO -7.7059e-01 (6s) Test: ELBO -7.6823e-01, Accuracy 0.904 (0s)
# [Epoch 42] Train: ELBO -7.7005e-01 (6s) Test: ELBO -7.6822e-01, Accuracy 0.906 (0s)
# [Epoch 43] Train: ELBO -7.6960e-01 (6s) Test: ELBO -7.6729e-01, Accuracy 0.905 (0s)
# [Epoch 44] Train: ELBO -7.6925e-01 (6s) Test: ELBO -7.6719e-01, Accuracy 0.910 (0s)
# [Epoch 45] Train: ELBO -7.6915e-01 (6s) Test: ELBO -7.6738e-01, Accuracy 0.908 (0s)
# [Epoch 46] Train: ELBO -7.6835e-01 (6s) Test: ELBO -7.6575e-01, Accuracy 0.908 (0s)
# [Epoch 47] Train: ELBO -7.6821e-01 (6s) Test: ELBO -7.6666e-01, Accuracy 0.912 (0s)
# [Epoch 48] Train: ELBO -7.6778e-01 (6s) Test: ELBO -7.6546e-01, Accuracy 0.911 (0s)
# [Epoch 49] Train: ELBO -7.6750e-01 (6s) Test: ELBO -7.6595e-01, Accuracy 0.912 (0s)
# [Epoch 50] Train: ELBO -7.6715e-01 (6s) Test: ELBO -7.6599e-01, Accuracy 0.913 (0s)
# [Epoch 51] Train: ELBO -7.6687e-01 (6s) Test: ELBO -7.6493e-01, Accuracy 0.913 (0s)
# [Epoch 52] Train: ELBO -7.6655e-01 (6s) Test: ELBO -7.6472e-01, Accuracy 0.913 (0s)
# [Epoch 53] Train: ELBO -7.6631e-01 (6s) Test: ELBO -7.6469e-01, Accuracy 0.918 (0s)
# [Epoch 54] Train: ELBO -7.6590e-01 (6s) Test: ELBO -7.6343e-01, Accuracy 0.915 (0s)
# [Epoch 55] Train: ELBO -7.6559e-01 (6s) Test: ELBO -7.6315e-01, Accuracy 0.915 (0s)
# [Epoch 56] Train: ELBO -7.6526e-01 (6s) Test: ELBO -7.6351e-01, Accuracy 0.922 (0s)
# [Epoch 57] Train: ELBO -7.6536e-01 (6s) Test: ELBO -7.6294e-01, Accuracy 0.920 (0s)
# [Epoch 58] Train: ELBO -7.6468e-01 (6s) Test: ELBO -7.6349e-01, Accuracy 0.919 (0s)
# [Epoch 59] Train: ELBO -7.6457e-01 (6s) Test: ELBO -7.6273e-01, Accuracy 0.918 (0s)
# [Epoch 60] Train: ELBO -7.6426e-01 (6s) Test: ELBO -7.6382e-01, Accuracy 0.922 (0s)
# [Epoch 61] Train: ELBO -7.6414e-01 (6s) Test: ELBO -7.6251e-01, Accuracy 0.920 (0s)
# [Epoch 62] Train: ELBO -7.6375e-01 (6s) Test: ELBO -7.6285e-01, Accuracy 0.923 (0s)
# [Epoch 63] Train: ELBO -7.6358e-01 (6s) Test: ELBO -7.6224e-01, Accuracy 0.920 (0s)
# [Epoch 64] Train: ELBO -7.6317e-01 (6s) Test: ELBO -7.6211e-01, Accuracy 0.916 (0s)
# [Epoch 65] Train: ELBO -7.6344e-01 (6s) Test: ELBO -7.6236e-01, Accuracy 0.921 (0s)
# [Epoch 66] Train: ELBO -7.6302e-01 (6s) Test: ELBO -7.6173e-01, Accuracy 0.927 (0s)
# [Epoch 67] Train: ELBO -7.6288e-01 (6s) Test: ELBO -7.6143e-01, Accuracy 0.926 (0s)
# [Epoch 68] Train: ELBO -7.6234e-01 (6s) Test: ELBO -7.6155e-01, Accuracy 0.924 (0s)
# [Epoch 69] Train: ELBO -7.6229e-01 (6s) Test: ELBO -7.6066e-01, Accuracy 0.925 (0s)
# [Epoch 70] Train: ELBO -7.6214e-01 (6s) Test: ELBO -7.6071e-01, Accuracy 0.926 (0s)
# [Epoch 71] Train: ELBO -7.6183e-01 (6s) Test: ELBO -7.6092e-01, Accuracy 0.923 (0s)
# [Epoch 72] Train: ELBO -7.6178e-01 (6s) Test: ELBO -7.6084e-01, Accuracy 0.928 (0s)
# [Epoch 73] Train: ELBO -7.6149e-01 (6s) Test: ELBO -7.6049e-01, Accuracy 0.927 (0s)
# [Epoch 74] Train: ELBO -7.6132e-01 (6s) Test: ELBO -7.5952e-01, Accuracy 0.927 (0s)
# [Epoch 75] Train: ELBO -7.6130e-01 (6s) Test: ELBO -7.5968e-01, Accuracy 0.929 (0s)
# [Epoch 76] Train: ELBO -7.6074e-01 (6s) Test: ELBO -7.6096e-01, Accuracy 0.929 (0s)
# [Epoch 77] Train: ELBO -7.6100e-01 (6s) Test: ELBO -7.5993e-01, Accuracy 0.928 (0s)
# [Epoch 78] Train: ELBO -7.6068e-01 (6s) Test: ELBO -7.5957e-01, Accuracy 0.929 (0s)
# [Epoch 79] Train: ELBO -7.6074e-01 (6s) Test: ELBO -7.6057e-01, Accuracy 0.929 (0s)
# [Epoch 80] Train: ELBO -7.6045e-01 (6s) Test: ELBO -7.5866e-01, Accuracy 0.931 (0s)
# [Epoch 81] Train: ELBO -7.6003e-01 (6s) Test: ELBO -7.5978e-01, Accuracy 0.928 (0s)
# [Epoch 82] Train: ELBO -7.5993e-01 (6s) Test: ELBO -7.5977e-01, Accuracy 0.932 (0s)
# [Epoch 83] Train: ELBO -7.5966e-01 (6s) Test: ELBO -7.5896e-01, Accuracy 0.929 (0s)
# [Epoch 84] Train: ELBO -7.5977e-01 (6s) Test: ELBO -7.5810e-01, Accuracy 0.930 (0s)
# [Epoch 85] Train: ELBO -7.5943e-01 (6s) Test: ELBO -7.5878e-01, Accuracy 0.930 (0s)
# [Epoch 86] Train: ELBO -7.5931e-01 (6s) Test: ELBO -7.5821e-01, Accuracy 0.934 (0s)
# [Epoch 87] Train: ELBO -7.5897e-01 (6s) Test: ELBO -7.5872e-01, Accuracy 0.929 (0s)
# [Epoch 88] Train: ELBO -7.5905e-01 (6s) Test: ELBO -7.5984e-01, Accuracy 0.929 (0s)
# [Epoch 89] Train: ELBO -7.5895e-01 (6s) Test: ELBO -7.5862e-01, Accuracy 0.930 (0s)
# [Epoch 90] Train: ELBO -7.5855e-01 (6s) Test: ELBO -7.5861e-01, Accuracy 0.937 (0s)
# [Epoch 91] Train: ELBO -7.5866e-01 (6s) Test: ELBO -7.5824e-01, Accuracy 0.934 (0s)
# [Epoch 92] Train: ELBO -7.5841e-01 (6s) Test: ELBO -7.5758e-01, Accuracy 0.934 (0s)
# [Epoch 93] Train: ELBO -7.5837e-01 (6s) Test: ELBO -7.5769e-01, Accuracy 0.936 (0s)
# [Epoch 94] Train: ELBO -7.5797e-01 (6s) Test: ELBO -7.5803e-01, Accuracy 0.938 (0s)
# [Epoch 95] Train: ELBO -7.5815e-01 (6s) Test: ELBO -7.5730e-01, Accuracy 0.937 (0s)
# [Epoch 96] Train: ELBO -7.5778e-01 (6s) Test: ELBO -7.5671e-01, Accuracy 0.941 (0s)
# [Epoch 97] Train: ELBO -7.5757e-01 (6s) Test: ELBO -7.5725e-01, Accuracy 0.937 (0s)
# [Epoch 98] Train: ELBO -7.5744e-01 (6s) Test: ELBO -7.5706e-01, Accuracy 0.940 (0s)
# [Epoch 99] Train: ELBO -7.5766e-01 (6s) Test: ELBO -7.5687e-01, Accuracy 0.936 (0s)
# [Epoch 100] Train: ELBO -7.5718e-01 (6s) Test: ELBO -7.5643e-01, Accuracy 0.937 (0s)
# [Epoch 101] Train: ELBO -7.5712e-01 (6s) Test: ELBO -7.5757e-01, Accuracy 0.942 (0s)
# [Epoch 102] Train: ELBO -7.5712e-01 (6s) Test: ELBO -7.5638e-01, Accuracy 0.940 (0s)
# [Epoch 103] Train: ELBO -7.5695e-01 (6s) Test: ELBO -7.5717e-01, Accuracy 0.936 (0s)
# [Epoch 104] Train: ELBO -7.5663e-01 (6s) Test: ELBO -7.5636e-01, Accuracy 0.937 (0s)
# [Epoch 105] Train: ELBO -7.5677e-01 (6s) Test: ELBO -7.5719e-01, Accuracy 0.938 (0s)
# [Epoch 106] Train: ELBO -7.5641e-01 (6s) Test: ELBO -7.5648e-01, Accuracy 0.940 (0s)
# [Epoch 107] Train: ELBO -7.5641e-01 (6s) Test: ELBO -7.5628e-01, Accuracy 0.942 (0s)
# [Epoch 108] Train: ELBO -7.5637e-01 (6s) Test: ELBO -7.5546e-01, Accuracy 0.937 (0s)
# [Epoch 109] Train: ELBO -7.5601e-01 (6s) Test: ELBO -7.5649e-01, Accuracy 0.944 (0s)
# [Epoch 110] Train: ELBO -7.5609e-01 (6s) Test: ELBO -7.5616e-01, Accuracy 0.942 (0s)
# [Epoch 111] Train: ELBO -7.5597e-01 (6s) Test: ELBO -7.5532e-01, Accuracy 0.941 (0s)
# [Epoch 112] Train: ELBO -7.5567e-01 (6s) Test: ELBO -7.5594e-01, Accuracy 0.941 (0s)
# [Epoch 113] Train: ELBO -7.5570e-01 (6s) Test: ELBO -7.5525e-01, Accuracy 0.942 (0s)
# [Epoch 114] Train: ELBO -7.5570e-01 (6s) Test: ELBO -7.5489e-01, Accuracy 0.944 (0s)
# [Epoch 115] Train: ELBO -7.5557e-01 (6s) Test: ELBO -7.5548e-01, Accuracy 0.941 (0s)
# [Epoch 116] Train: ELBO -7.5543e-01 (6s) Test: ELBO -7.5555e-01, Accuracy 0.941 (0s)
# [Epoch 117] Train: ELBO -7.5505e-01 (6s) Test: ELBO -7.5666e-01, Accuracy 0.941 (0s)
# [Epoch 118] Train: ELBO -7.5519e-01 (6s) Test: ELBO -7.5460e-01, Accuracy 0.944 (0s)
# [Epoch 119] Train: ELBO -7.5511e-01 (6s) Test: ELBO -7.5552e-01, Accuracy 0.941 (0s)
# [Epoch 120] Train: ELBO -7.5501e-01 (6s) Test: ELBO -7.5500e-01, Accuracy 0.943 (0s)
# [Epoch 121] Train: ELBO -7.5475e-01 (6s) Test: ELBO -7.5542e-01, Accuracy 0.943 (0s)
# [Epoch 122] Train: ELBO -7.5473e-01 (6s) Test: ELBO -7.5473e-01, Accuracy 0.940 (0s)
# [Epoch 123] Train: ELBO -7.5465e-01 (6s) Test: ELBO -7.5437e-01, Accuracy 0.943 (0s)
# [Epoch 124] Train: ELBO -7.5449e-01 (6s) Test: ELBO -7.5501e-01, Accuracy 0.942 (0s)
# [Epoch 125] Train: ELBO -7.5466e-01 (6s) Test: ELBO -7.5458e-01, Accuracy 0.944 (0s)
# [Epoch 126] Train: ELBO -7.5449e-01 (6s) Test: ELBO -7.5392e-01, Accuracy 0.943 (0s)
# [Epoch 127] Train: ELBO -7.5426e-01 (6s) Test: ELBO -7.5466e-01, Accuracy 0.946 (0s)
# [Epoch 128] Train: ELBO -7.5405e-01 (6s) Test: ELBO -7.5462e-01, Accuracy 0.943 (0s)
# [Epoch 129] Train: ELBO -7.5378e-01 (6s) Test: ELBO -7.5518e-01, Accuracy 0.942 (0s)
# [Epoch 130] Train: ELBO -7.5397e-01 (6s) Test: ELBO -7.5380e-01, Accuracy 0.941 (0s)
# [Epoch 131] Train: ELBO -7.5383e-01 (6s) Test: ELBO -7.5452e-01, Accuracy 0.946 (0s)
# [Epoch 132] Train: ELBO -7.5364e-01 (6s) Test: ELBO -7.5300e-01, Accuracy 0.945 (0s)
# [Epoch 133] Train: ELBO -7.5359e-01 (6s) Test: ELBO -7.5332e-01, Accuracy 0.941 (0s)
# [Epoch 134] Train: ELBO -7.5347e-01 (6s) Test: ELBO -7.5461e-01, Accuracy 0.947 (0s)
# [Epoch 135] Train: ELBO -7.5359e-01 (6s) Test: ELBO -7.5427e-01, Accuracy 0.947 (0s)
# [Epoch 136] Train: ELBO -7.5335e-01 (6s) Test: ELBO -7.5297e-01, Accuracy 0.945 (0s)
# [Epoch 137] Train: ELBO -7.5318e-01 (6s) Test: ELBO -7.5331e-01, Accuracy 0.941 (0s)
# [Epoch 138] Train: ELBO -7.5318e-01 (6s) Test: ELBO -7.5345e-01, Accuracy 0.945 (0s)
# [Epoch 139] Train: ELBO -7.5311e-01 (6s) Test: ELBO -7.5331e-01, Accuracy 0.945 (0s)
# [Epoch 140] Train: ELBO -7.5315e-01 (6s) Test: ELBO -7.5283e-01, Accuracy 0.943 (0s)
# [Epoch 141] Train: ELBO -7.5301e-01 (6s) Test: ELBO -7.5280e-01, Accuracy 0.946 (0s)
# [Epoch 142] Train: ELBO -7.5281e-01 (6s) Test: ELBO -7.5320e-01, Accuracy 0.948 (0s)
# [Epoch 143] Train: ELBO -7.5281e-01 (6s) Test: ELBO -7.5228e-01, Accuracy 0.945 (0s)
# [Epoch 144] Train: ELBO -7.5250e-01 (6s) Test: ELBO -7.5288e-01, Accuracy 0.948 (0s)
# [Epoch 145] Train: ELBO -7.5246e-01 (6s) Test: ELBO -7.5262e-01, Accuracy 0.946 (0s)
# [Epoch 146] Train: ELBO -7.5250e-01 (6s) Test: ELBO -7.5230e-01, Accuracy 0.948 (0s)
# [Epoch 147] Train: ELBO -7.5254e-01 (6s) Test: ELBO -7.5191e-01, Accuracy 0.943 (0s)
# [Epoch 148] Train: ELBO -7.5247e-01 (6s) Test: ELBO -7.5229e-01, Accuracy 0.948 (0s)
# [Epoch 149] Train: ELBO -7.5216e-01 (6s) Test: ELBO -7.5297e-01, Accuracy 0.947 (0s)
# [Epoch 150] Train: ELBO -7.5241e-01 (6s) Test: ELBO -7.5193e-01, Accuracy 0.946 (0s)
# [Epoch 151] Train: ELBO -7.5213e-01 (6s) Test: ELBO -7.5309e-01, Accuracy 0.947 (0s)
# [Epoch 152] Train: ELBO -7.5203e-01 (6s) Test: ELBO -7.5151e-01, Accuracy 0.949 (0s)
# [Epoch 153] Train: ELBO -7.5203e-01 (6s) Test: ELBO -7.5178e-01, Accuracy 0.947 (0s)
# [Epoch 154] Train: ELBO -7.5198e-01 (6s) Test: ELBO -7.5184e-01, Accuracy 0.949 (0s)
# [Epoch 155] Train: ELBO -7.5202e-01 (6s) Test: ELBO -7.5189e-01, Accuracy 0.948 (0s)
# [Epoch 156] Train: ELBO -7.5196e-01 (6s) Test: ELBO -7.5122e-01, Accuracy 0.946 (0s)
# [Epoch 157] Train: ELBO -7.5151e-01 (6s) Test: ELBO -7.5237e-01, Accuracy 0.948 (0s)
# [Epoch 158] Train: ELBO -7.5159e-01 (6s) Test: ELBO -7.5369e-01, Accuracy 0.947 (0s)
# [Epoch 159] Train: ELBO -7.5159e-01 (6s) Test: ELBO -7.5286e-01, Accuracy 0.947 (0s)
# [Epoch 160] Train: ELBO -7.5151e-01 (6s) Test: ELBO -7.5119e-01, Accuracy 0.950 (0s)
# [Epoch 161] Train: ELBO -7.5150e-01 (6s) Test: ELBO -7.5233e-01, Accuracy 0.946 (0s)
# [Epoch 162] Train: ELBO -7.5128e-01 (6s) Test: ELBO -7.5123e-01, Accuracy 0.948 (0s)
# [Epoch 163] Train: ELBO -7.5118e-01 (6s) Test: ELBO -7.5156e-01, Accuracy 0.949 (0s)
# [Epoch 164] Train: ELBO -7.5115e-01 (6s) Test: ELBO -7.5198e-01, Accuracy 0.948 (0s)
# [Epoch 165] Train: ELBO -7.5141e-01 (6s) Test: ELBO -7.5169e-01, Accuracy 0.951 (0s)
# [Epoch 166] Train: ELBO -7.5116e-01 (6s) Test: ELBO -7.5134e-01, Accuracy 0.949 (0s)
# [Epoch 167] Train: ELBO -7.5107e-01 (6s) Test: ELBO -7.5136e-01, Accuracy 0.950 (0s)
# [Epoch 168] Train: ELBO -7.5101e-01 (6s) Test: ELBO -7.5199e-01, Accuracy 0.948 (0s)
# [Epoch 169] Train: ELBO -7.5086e-01 (6s) Test: ELBO -7.5081e-01, Accuracy 0.949 (0s)
# [Epoch 170] Train: ELBO -7.5072e-01 (6s) Test: ELBO -7.5150e-01, Accuracy 0.945 (0s)
# [Epoch 171] Train: ELBO -7.5089e-01 (6s) Test: ELBO -7.5117e-01, Accuracy 0.950 (0s)
# [Epoch 172] Train: ELBO -7.5055e-01 (6s) Test: ELBO -7.5212e-01, Accuracy 0.948 (0s)
# [Epoch 173] Train: ELBO -7.5066e-01 (6s) Test: ELBO -7.5089e-01, Accuracy 0.950 (0s)
# [Epoch 174] Train: ELBO -7.5043e-01 (6s) Test: ELBO -7.5118e-01, Accuracy 0.947 (0s)
# [Epoch 175] Train: ELBO -7.5052e-01 (6s) Test: ELBO -7.5109e-01, Accuracy 0.950 (0s)
# [Epoch 176] Train: ELBO -7.5073e-01 (6s) Test: ELBO -7.5060e-01, Accuracy 0.947 (0s)
# [Epoch 177] Train: ELBO -7.5037e-01 (6s) Test: ELBO -7.5065e-01, Accuracy 0.946 (0s)
# [Epoch 178] Train: ELBO -7.5012e-01 (6s) Test: ELBO -7.5032e-01, Accuracy 0.950 (0s)
# [Epoch 179] Train: ELBO -7.5029e-01 (6s) Test: ELBO -7.5066e-01, Accuracy 0.950 (0s)
# [Epoch 180] Train: ELBO -7.5012e-01 (6s) Test: ELBO -7.5066e-01, Accuracy 0.950 (0s)
# [Epoch 181] Train: ELBO -7.4996e-01 (6s) Test: ELBO -7.5087e-01, Accuracy 0.949 (0s)
# [Epoch 182] Train: ELBO -7.5006e-01 (6s) Test: ELBO -7.5007e-01, Accuracy 0.948 (0s)
# [Epoch 183] Train: ELBO -7.5007e-01 (6s) Test: ELBO -7.5085e-01, Accuracy 0.950 (0s)
# [Epoch 184] Train: ELBO -7.4989e-01 (6s) Test: ELBO -7.5163e-01, Accuracy 0.950 (0s)
# [Epoch 185] Train: ELBO -7.5014e-01 (6s) Test: ELBO -7.5103e-01, Accuracy 0.952 (0s)
# [Epoch 186] Train: ELBO -7.4968e-01 (6s) Test: ELBO -7.5063e-01, Accuracy 0.951 (0s)
# [Epoch 187] Train: ELBO -7.4980e-01 (6s) Test: ELBO -7.5070e-01, Accuracy 0.949 (0s)
# [Epoch 188] Train: ELBO -7.4968e-01 (6s) Test: ELBO -7.5063e-01, Accuracy 0.953 (0s)
# [Epoch 189] Train: ELBO -7.4977e-01 (6s) Test: ELBO -7.5087e-01, Accuracy 0.951 (0s)
# [Epoch 190] Train: ELBO -7.4983e-01 (6s) Test: ELBO -7.4940e-01, Accuracy 0.951 (0s)
# [Epoch 191] Train: ELBO -7.4934e-01 (6s) Test: ELBO -7.4990e-01, Accuracy 0.949 (0s)
# [Epoch 192] Train: ELBO -7.4950e-01 (6s) Test: ELBO -7.4981e-01, Accuracy 0.949 (0s)
# [Epoch 193] Train: ELBO -7.4953e-01 (6s) Test: ELBO -7.4962e-01, Accuracy 0.952 (0s)
# [Epoch 194] Train: ELBO -7.4926e-01 (6s) Test: ELBO -7.4881e-01, Accuracy 0.953 (0s)
# [Epoch 195] Train: ELBO -7.4936e-01 (6s) Test: ELBO -7.4934e-01, Accuracy 0.951 (0s)
# [Epoch 196] Train: ELBO -7.4910e-01 (6s) Test: ELBO -7.5000e-01, Accuracy 0.951 (0s)
# [Epoch 197] Train: ELBO -7.4933e-01 (6s) Test: ELBO -7.4961e-01, Accuracy 0.952 (0s)
# [Epoch 198] Train: ELBO -7.4933e-01 (6s) Test: ELBO -7.5055e-01, Accuracy 0.955 (0s)
# [Epoch 199] Train: ELBO -7.4922e-01 (6s) Test: ELBO -7.4990e-01, Accuracy 0.951 (0s)

# %%
if RESTORE:
    enc.load_state_dict(torch.load('%s/%s-%s-%s-enc.rar' % (WEIGHTS_PATH, MODEL_NAME, probtorch.__version__, torch.__version__)))
    dec.load_state_dict(torch.load('%s/%s-%s-%s-dec.rar' % (WEIGHTS_PATH, MODEL_NAME, probtorch.__version__, torch.__version__)))

# %%
print('[encoder] ELBO: %e, ACCURACY: %f' % test(test_data, enc, dec, infer=False))
print('[encoder+inference] ELBO: %e, ACCURACY: %f' % test(test_data, enc, dec, infer=True))
# Out:
# [encoder] ELBO: -7.498017e-01, ACCURACY: 0.186536
# [encoder+inference] ELBO: -7.498248e-01, ACCURACY: 0.951322

# %% [markdown]
# # Visualize Embeddings

# %%
import numpy as np
ys = []
zs = []
for (x, y) in test_data:
    if len(x) == NUM_BATCH:
        images = x.view(-1, NUM_PIXELS)
        if CUDA:
            q = enc(images.cuda())
            z = q['styles'].value.cpu().detach().numpy()
        else:
            q = enc(images)
            z = q['styles'].value.data.detach().numpy()
        zs.append(z)
        ys.append(y.numpy())
ys = np.concatenate(ys,0)
zs = np.concatenate(zs,0)

# %%
# run TSNE when number of latent dims exceeds 2
if NUM_STYLE > 2:
    from sklearn.manifold import TSNE
    zs2 = TSNE().fit_transform(zs)
    zs2_mean = zs2.mean(0)
    zs2_std = zs2.std(0)
else:
    zs2 = zs

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# display a 2D plot of the digit classes in the latent space
fig = plt.figure(figsize=(6,6))
ax = plt.gca()

colors = []
for k in range(10):
    m = (ys == k)
    p = ax.scatter(zs2[m, 0], zs2[m, 1], label='y=%d' % k, alpha=0.5, s=5)
    colors.append(p.get_facecolor())
ax.legend()

fig.tight_layout()
#fig.savefig('images/%s-%02d-encodings.png' % (MODEL_NAME, NUM_STYLE), dpi=300)

x_lim = ax.get_xlim()
y_lim = ax.get_ylim()

# %%
# display a 2D plot of the digit classes in the latent space
fig = plt.figure(figsize=(10,4.25))

for k in range(10):
    ax = plt.subplot(2,5,k+1)
    m = (ys == k)
    ax.scatter(zs2[m, 0], zs2[m, 1], alpha=0.5, s=5, c=colors[k])
    ax.set_xlim(x_lim)
    ax.set_ylim(y_lim)
    ax.set_title('y=%d' % k)

fig.tight_layout()

# %% [markdown]
# # Visualize Reconstructed Digits

# %%
x,_ = next(iter(train_data))
x_var = x.view(-1, NUM_PIXELS)
if CUDA:
    q = enc(x_var.cuda())
    p = dec(x_var.cuda(), q)
    x_mean = p['images'].value.view(NUM_BATCH, 28, 28).data.cpu().numpy()
else:
    q = enc(x_var)
    p = dec(x_var, q)
    x_mean = p['images'].value.view(NUM_BATCH, 28, 28).data.numpy().squeeze()
    
fig = plt.figure(figsize=(12,5.25))
for k in range(5):
    ax = plt.subplot(2, 5, k+1)
    ax.imshow(x[k].squeeze())
    #ax.set_title("original")
    plt.axis("off")
    ax = plt.subplot(2, 5, k+6)
    ax.imshow(x_mean[k].squeeze())
    #ax.set_title("reconstructed")
    plt.axis("off")
    
fig.tight_layout()
#fig.savefig('images/%s-%02d-reconstructions-separate.png' % (MODEL_NAME, NUM_STYLE), dpi=300, facecolor=[0,0,0,0])

# %%
# display a 2D manifold of the digits
n = 7  # figure with 15x15 digits
digit_size = 28
figure = np.zeros((digit_size * n, digit_size * n))
# linearly spaced coordinates on the unit square were transformed through the inverse CDF (ppf) of the Gaussian
# to produce values of the latent variables z, since the prior of the latent space is Gaussian
grid_x = norm.ppf(np.linspace(0.05, 0.95, n))
grid_y = norm.ppf(np.linspace(0.05, 0.95, n))
null_image = torch.tensor(np.zeros((1, 784), 'f'))

plt.figure(figsize=(12, 30))
for y in range(10):
    plt.subplot(5, 2, y+1)
    y_hot = np.zeros((1,10), 'f')
    y_hot[0,y] = 1
    y_hot = torch.tensor(y_hot)
    my = (ys == y)
    for i, z0i in enumerate(grid_x):
        for j, z1j in enumerate(grid_y[-1::-1]):
            z = np.array([[z0i, z1j]], 'f')
            if NUM_STYLE > 2:
                z = zs2_mean[None,:] + zs2_std[None,:] * z
                n = ((zs2[my] - z)**2).sum(1).argmin()
                z = zs[my][n][None,:]
            z = torch.tensor(z)
            if CUDA:
                p = dec(null_image.cuda(), {'styles': z.cuda(), 'digits': y_hot.cuda()})
                images = p['images'].value.data.cpu().numpy()
            else:
                p = dec(null_image, {'styles': z, 'digits': y_hot})
                images = p['images'].value.data.numpy()
            digit = images.reshape(digit_size, digit_size)
            figure[j * digit_size: (j + 1) * digit_size,
                   i * digit_size: (i + 1) * digit_size] = digit
    plt.imshow(figure)
    plt.title('y=%d' % y)
    plt.axis('off')
plt.show()
